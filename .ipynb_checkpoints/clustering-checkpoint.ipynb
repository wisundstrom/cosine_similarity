# %%
import pyspark
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pyspark.sql import SparkSession
from scipy.spatial import ConvexHull
from sklearn import datasets
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import davies_bouldin_score, silhouette_score, calinski_harabasz_score
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.decomposition import PCA
from pyspark.sql.functions import pandas_udf, PandasUDFType
from pyspark.sql import Window
from pyspark.ml.feature import Normalizer
from pyspark.mllib.linalg.distributed import *
from pyspark.sql.types import *
from pyspark.sql.functions import *
from scipy.stats import *
from sklearn.cluster import KMeans, OPTICS, DBSCAN, cluster_optics_dbscan, MiniBatchKMeans

import time

import matplotlib.pyplot as plt
import seaborn as sns
import os
# %matplotlib inline
os.environ['ARROW_PRE_0_15_IPC_FORMAT']='1'

# %%
sc = SparkSession.builder.getOrCreate()
sc.conf.set("spark.sql.execution.arrow.enabled", "true")

# %%
test_data = datasets.make_blobs(
    n_samples = 700000, centers = 7, n_features = 2, cluster_std = [20,200,20,200,200,200,200], shuffle = False,
    random_state = 15, center_box=(500,3500))

df_agi = pd.DataFrame(test_data[0])
df_agi.columns = ['AGI','Refund']
df_agi['label'] = test_data[1]
df_agi['id'] = df_agi.index
df_agi["AGI"] = df_agi["AGI"] * 20

# %%
SAMPLE_AMOUNT = 500

samp_clust_01 = df_agi.sample(SAMPLE_AMOUNT)
samp_clust_02 = df_agi[((df_agi["label"] == 0) | (df_agi["label"] == 1))].sample(SAMPLE_AMOUNT)
samp_clust_03 = df_agi[((df_agi["label"] == 0) | (df_agi["label"] == 2))].sample(SAMPLE_AMOUNT)
samp_clust_04 = df_agi[((df_agi["label"] == 1) | (df_agi["label"] == 3) | (df_agi["label"] == 5))].sample(SAMPLE_AMOUNT)
samp_clusters = [samp_clust_01, samp_clust_02, samp_clust_03, samp_clust_04]

# %%
sns.set_style("darkgrid")

g = sns.scatterplot(x = df_agi.AGI, y = df_agi.Refund, hue = df_agi.label, palette='bright')
fig = plt.gcf()
fig.set_size_inches(10,10)
plt.legend(labels = ["0", "1", "2", "3", "4", "5", "6"])
plt.show()

# %%
def cluster_scaler(cluster, minmax = True):
    
    data = np.array(cluster.loc[:,['AGI','Refund']])
    
    if minmax:
        minmax = MinMaxScaler()
        return minmax.fit_transform(data)
    
    else:
        z_scale = StandardScaler()
        return z_scale.fit_transform(data)

# %%
minmaxed_samples = [cluster_scaler(cluster) for cluster in samp_clusters]

# %%
minmaxed_samples[0];

# %%
sns.scatterplot(minmaxed_samples[0][:,0],minmaxed_samples[0][:,1])

# %% [markdown]
# ## Experimenting with local density based clustering (DBSCAN and OPTICS)

# %%
clust = OPTICS().fit(minmaxed_samples[0])

# %%
labels_050 = cluster_optics_dbscan(reachability=clust.reachability_,
                                   core_distances=clust.core_distances_,
                                   ordering=clust.ordering_, eps=0.5)
labels_010 = cluster_optics_dbscan(reachability=clust.reachability_,
                                   core_distances=clust.core_distances_,
                                   ordering=clust.ordering_, eps=.1)
labels_025 = cluster_optics_dbscan(reachability=clust.reachability_,
                                   core_distances=clust.core_distances_,
                                   ordering=clust.ordering_, eps=0.25)

# %%
sns.scatterplot(minmaxed_samples[0][:,0],minmaxed_samples[0][:,1], hue=labels_010)

# %% [markdown]
# one option would be to run dbscan or optics, and then use the mean distance to each cluster centroid (or min or max) as metrics.

# %% [markdown]
# ## Experimenting With Kmeans and kmeans like methods
# the idea here is to run kmeans with a series of numbers of clusters, then take the max silhouette ( or min db) score as the measurement of clustering ( if kmeans does not scale well once we use larger sets of data, MiniBatch Kmeans can help with speed things up.)

# %%
# 
kmeans = KMeans(n_clusters= 4)
clusters = kmeans.fit_predict(minmaxed_samples[0])
sns.scatterplot(minmaxed_samples[0][:,0],minmaxed_samples[0][:,1], hue=clusters)

# %%
clusters.shape
# Out:
# (500,)

# %%
def kmeans_scores(samples, max_clusters=10, return_all = False, timed = False):
    db_scores = []
    sil_scores = []
    ch_scores = []
    labels = []
    t00 = time.time()
    
    
    for i in range(2, max_clusters):
        t1 = time.time()
        kmeans = KMeans(n_clusters= i)
        clusters = kmeans.fit_predict(samples)
        t2 = time.time()
        db_score = davies_bouldin_score(samples, clusters)
        t3 = time.time()
        sil_score = silhouette_score(samples, clusters)
        t4 = time.time()
        ch_score = calinski_harabasz_score(samples, clusters)
        t5 = time.time()
        
        
        db_scores.append(db_score)
        sil_scores.append(sil_score)
        ch_scores.append(ch_score)
        
        if timed:
            
            print(f" times| Kmeans: {t2-t1}, db score: {t3-t2}, sil score {t4-t3}, ch score {t5-t4} ")
        
        if return_all:
            labels.append(clusters)
            
    t11= time.time()
    print(f"Total Time = {t11-t00}")
    if return_all:
        return db_scores, sil_scores, ch_scores, labels
    else:
        return np.min(db_scores), np.max(sil_scores), np.max(ch_scores)

# %%
db_scores, sil_scores, ch_scores, labels = kmeans_scores(minmaxed_samples[0], max_clusters=10, return_all = True)
# Out:
# Total Time = 0.3463723659515381

# %%
sns.lineplot(y=ch_scores, x=range(2,10))

# %%
sns.lineplot(y=sil_scores, x=range(2,10))

# %%
sns.lineplot(y=db_scores, x=range(2,10))

# %%
scores = [kmeans_scores(sample, max_clusters=10) for sample in minmaxed_samples]
# Out:
# Total Time = 0.37411046028137207
# Total Time = 0.33408069610595703
# Total Time = 0.24793291091918945
# Total Time = 0.36423659324645996

# %%
scores
# Out:
# [(0.38195492750267723, 0.7126871412104478, 1971.4872009446208),
#  (0.20054938085014337, 0.8662270717584538, 7498.616533171039),
#  (0.027445443962427526, 0.9805112416737279, 503587.77264576603),
#  (0.5253477769315753, 0.6296907877698031, 1176.6915777182253)]

# %%
SAMPLE_AMOUNT = 10000

samp_clust_01 = df_agi.sample(SAMPLE_AMOUNT)
samp_clust_02 = df_agi[((df_agi["label"] == 0) | (df_agi["label"] == 1))].sample(SAMPLE_AMOUNT)
samp_clust_03 = df_agi[((df_agi["label"] == 0) | (df_agi["label"] == 2))].sample(SAMPLE_AMOUNT)
samp_clust_04 = df_agi[((df_agi["label"] == 1) | (df_agi["label"] == 3) | (df_agi["label"] == 5))].sample(SAMPLE_AMOUNT)
samp_clusters = [samp_clust_01, samp_clust_02, samp_clust_03, samp_clust_04]
minmaxed_samples = [cluster_scaler(cluster) for cluster in samp_clusters]

# %%
scores2 = [kmeans_scores(sample, max_clusters=10, timed=True) for sample in minmaxed_samples]
scores2
# Out:
#  times| Kmeans: 0.07765460014343262, db score: 0.0015478134155273438, sil score 2.0247228145599365, ch score 0.026445865631103516
#  times| Kmeans: 0.08865189552307129, db score: 0.00524592399597168, sil score 1.1739981174468994, ch score 0.0012063980102539062
#  times| Kmeans: 0.07866501808166504, db score: 0.0023310184478759766, sil score 1.0406010150909424, ch score 0.0012514591217041016
#  times| Kmeans: 0.09296703338623047, db score: 0.006857872009277344, sil score 0.9791784286499023, ch score 0.0013344287872314453
#  times| Kmeans: 0.0951223373413086, db score: 0.0034215450286865234, sil score 1.000950574874878, ch score 0.001383066177368164
#  times| Kmeans: 0.11771345138549805, db score: 0.0039730072021484375, sil score 0.9623723030090332, ch score 0.0015590190887451172
#  times| Kmeans: 0.14432072639465332, db score: 0.003312826156616211, sil score 0.942406177520752, ch score 0.0016086101531982422
# ...

# %% [markdown]
# The results are still agreeing with our other methods at 10k samples per cluster, in two dimensions. A benefit to this method vs the histogram methods is that these can be expanded to more than two dimensions. Silhouette score, in particular, requires computing many (but not all) pairwise distances so I am concerned about how that will scale to larger sample sizes and dimensions. The davies bouldin score, and even more so the calinski-habarasz index, seem to be faster. davies bouldin is defined in terms of cluster diameter (avg centroid distance) and distances between cetnroids, and calinski habarasz is defined in terms of squared centroid distances, which (should) reduce the computational complexity compared to silhoutette score

# %%
def kmeans_scores2(samples, max_clusters=10, timed = False, mini=False):
    db_scores = []
    sil_scores = []
    ch_scores = []
    t00 = time.time()
    
    for i in range(2, max_clusters):
        if mini:
            kmeans = MiniBatchKMeans(n_clusters=i)
        else:
            kmeans = KMeans(n_clusters= i)
        
        t1 = time.time()
        clusters = kmeans.fit_predict(samples)
        t2 = time.time()
        db_score = davies_bouldin_score(samples, clusters)
        t3 = time.time()
        ch_score = calinski_harabasz_score(samples, clusters)
        t4 = time.time()
        
        
        db_scores.append(db_score)
        ch_scores.append(ch_score)
        
        if timed:
            
            print(f" times| Kmeans: {t2-t1}, db score: {t3-t2},ch score {t4-t3} ")
            
    t11= time.time()
    print(f"Total Time = {t11-t00}")
    
    return np.min(db_scores), np.max(ch_scores)

# %%
SAMPLE_AMOUNT = 100000

samp_clust_01 = df_agi.sample(SAMPLE_AMOUNT)
samp_clust_02 = df_agi[((df_agi["label"] == 0) | (df_agi["label"] == 1))].sample(SAMPLE_AMOUNT)
samp_clust_03 = df_agi[((df_agi["label"] == 0) | (df_agi["label"] == 2))].sample(SAMPLE_AMOUNT)
samp_clust_04 = df_agi[((df_agi["label"] == 1) | (df_agi["label"] == 3) | (df_agi["label"] == 5))].sample(SAMPLE_AMOUNT)
samp_clusters = [samp_clust_01, samp_clust_02, samp_clust_03, samp_clust_04]
minmaxed_samples = [cluster_scaler(cluster) for cluster in samp_clusters]

# %%
scores3 = [kmeans_scores2(sample, max_clusters=10, timed=True) for sample in minmaxed_samples]
scores3
# Out:
#  times| Kmeans: 0.22515058517456055, db score: 0.007650136947631836,ch score 0.0077207088470458984
#  times| Kmeans: 0.2876462936401367, db score: 0.012939214706420898,ch score 0.013176441192626953
#  times| Kmeans: 0.5251874923706055, db score: 0.009100198745727539,ch score 0.008902549743652344
#  times| Kmeans: 0.5684669017791748, db score: 0.00964045524597168,ch score 0.009206533432006836
#  times| Kmeans: 0.5541231632232666, db score: 0.010111331939697266,ch score 0.009482860565185547
#  times| Kmeans: 0.9010424613952637, db score: 0.012566089630126953,ch score 0.009862899780273438
#  times| Kmeans: 0.8606653213500977, db score: 0.026177406311035156,ch score 0.010097503662109375
#  times| Kmeans: 1.2068567276000977, db score: 0.01170969009399414,ch score 0.010485410690307617
# Total Time = 5.308688163757324
#  times| Kmeans: 0.13814067840576172, db score: 0.007724761962890625,ch score 0.007828712463378906
# ...

# %%
scores4 = [kmeans_scores2(sample, max_clusters=10, timed=True, mini=True) for sample in minmaxed_samples]
scores4
# Out:
#  times| Kmeans: 0.40912508964538574, db score: 0.016424894332885742,ch score 0.007851839065551758
#  times| Kmeans: 0.3519279956817627, db score: 0.02566242218017578,ch score 0.008318662643432617
#  times| Kmeans: 0.35348987579345703, db score: 0.009787797927856445,ch score 0.008921146392822266
#  times| Kmeans: 0.5323641300201416, db score: 0.009814262390136719,ch score 0.009151697158813477
#  times| Kmeans: 0.47148823738098145, db score: 0.010289669036865234,ch score 0.00942230224609375
#  times| Kmeans: 0.3695340156555176, db score: 0.01064300537109375,ch score 0.009761571884155273
#  times| Kmeans: 0.3869173526763916, db score: 0.01102137565612793,ch score 0.010002613067626953
#  times| Kmeans: 0.7820162773132324, db score: 0.011571645736694336,ch score 0.010402441024780273
# Total Time = 3.836815357208252
#  times| Kmeans: 0.34705090522766113, db score: 0.007746696472167969,ch score 0.00787210464477539
# ...

# %% [markdown]
# Using mini-batch kmeans I was able to get the compute time to about 4s per group to aggregate on, with 100k samples per group. There is also probably more performance tuning possible with the settings for the minibatch kmeans, especially since we do not need the clusters to be terribly accurate for this purpose.
